# %% [markdown]
# <a href="https://colab.research.google.com/github/saanvikompelli-cmd/2520030083_ML/blob/main/Practical/Python_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PROGRAM-1 VARIABLES & TYPES

# %%
x = 5
y = 9.49
name = "CGPA"
is_student = True

print(x, type(x))
print(y, type(y))
print(name, type(name))
print(is_student, type(is_student))
# Out:
# 5 <class 'int'>
# 9.49 <class 'float'>
# CGPA <class 'str'>
# True <class 'bool'>

# %% [markdown]
# PROGRAM-2 ARITHMETIC OPERATORS

# %%
a = 7
b = 2
print("a + b", a + b)
print("a - b", a - b)
print("a * b", a * b)
print("a / b", a / b)
print("a % b", a % b)
print("a ** 2", a ** 2)
print("a // b", a // b)
# Out:
# a + b 9
# a - b 5
# a * b 14
# a / b 3.5
# a % b 1
# a ** 2 49
# a // b 3

# %% [markdown]
# PROGRAM-3 COMPARISION OPERATIONS

# %%
cgpa = 8.4
print("cgpa > 8 :", cgpa > 8)
print("cgpa < 8 :", cgpa < 8)
print("cgpa >= 8 :", cgpa >= 8)
print("cgpa < 8 :", cgpa <= 8)
print("cgpa == 8 :", cgpa == 8)
print("cgpa != 8 :", cgpa != 8)
# Out:
# cgpa > 8 : True
# cgpa < 8 : False
# cgpa >= 8 : True
# cgpa < 8 : False
# cgpa == 8 : False
# cgpa != 8 : True

# %% [markdown]
#  PROGRAM-4 LOGICAL OPERATORS: AND / OR / NOT

# %%
attendance = 85
placed = (cgpa > 85) and (attendance > 80)
print("placed:", placed)
placed = (cgpa > 85) or (attendance > 80)
print("placed:", placed)
placed = not (cgpa > 85)
print("placed:", placed)
# Out:
# placed: False
# placed: True
# placed: True

# %% [markdown]
# PROGRAM-5 F STRING

# %%
model_name = "Logistic Regression"
accuracy = 0.13408

# Old, clunky way (avoid this):
print("Accuracy of " + model_name + " is " + str(accuracy))

# f-string way (use this):
print(f"Accuracy of {model_name} is {accuracy}")

# ':.3f' inside the braces rounds a float to 3 decimal places -
# you will use this in almost every experiment to print clean metrics.
print(f"Accuracy of {model_name} is {accuracy:.3f}")
# Out:
# Accuracy of Logistic Regression is 0.13408
# Accuracy of Logistic Regression is 0.13408
# Accuracy of Logistic Regression is 0.134

# %% [markdown]
# PROGRAM-6 LISTS AND INDEXING

# %%
features = ["CGPA", "AptitudeTestScore", "CodingTestScore", "MockInterviewScore"]

print(features)
print(features[0])
print(features[1])
print(features[-1])
print(len(features))

# Slicing:
print(features[0:2])

# Adding to a list
features.append("Internships")
print(features)
# Out:
# ['CGPA', 'AptitudeTestScore', 'CodingTestScore', 'MockInterviewScore']
# CGPA
# AptitudeTestScore
# MockInterviewScore
# 4
# ['CGPA', 'AptitudeTestScore']
# ['CGPA', 'AptitudeTestScore', 'CodingTestScore', 'MockInterviewScore', 'Internships']

# %% [markdown]
# PROGRAM-7 DICTIONARY

# %%
# Create a dictionary
student = {
    "Name": "Saanvi",
    "Roll No": 83,
    "CGPA": 9.41
}

# Display all key-value pairs
print("Student Details:")
for key, value in student.items():
    print(key, ":", value)

# Access a specific key
print("\nStudent Name:", student["Name"])

# Machine Learning models dictionary
ml_models = {
    "Linear Regression": "Regression",
    "Decision Tree": "Classification",
    "Random Forest": "Ensemble"
}

print("\nMachine Learning Models:")
for model, model_type in ml_models.items():
    print(model, ":", model_type)
# Out:
# Student Details:
# Name : Saanvi
# Roll No : 83
# CGPA : 9.41
#
# Student Name: Saanvi
#
# Machine Learning Models:
# Linear Regression : Regression
# Decision Tree : Classification
# Random Forest : Ensemble

# %% [markdown]
# PROGRAM-8 CONDITIONAL STATEMENTS

# %%
# 1. Classify student's CGPA
cgpa = 8.3

if cgpa >= 8.5:
    print("Category: High")
elif cgpa >= 6.5:
    print("Category: Mid")
else:
    print("Category: Low")

# 2. Check for missing values in a dataset
data = [10, 20, None, 40]

if None in data:
    print("Missing values are present.")
else:
    print("No missing values.")

# 3. Check placement eligibility
if cgpa >= 7.0:
    print("Student is Eligible for Placement.")
else:
    print("Student is Not Eligible for Placement.")

# 4. Assign grades based on marks
marks = int(input("Enter Marks: "))

if marks >= 90:
    print("Grade: A")
elif marks >= 75:
    print("Grade: B")
elif marks >= 60:
    print("Grade: C")
elif marks >= 40:
    print("Grade: D")
else:
    print("Grade: F")
# Out:
# Category: Mid
# Missing values are present.
# Student is Eligible for Placement.
# Enter Marks: 76
# Grade: B

# %% [markdown]
# PROGRAM-9 LOOPS

# %%
numbers = [10, 25, 40, 15, 60, 35, 80]
threshold = 30

# 1. Display all elements
print("List Elements:")
for num in numbers:
    print(num)

# 2. Calculate average
sum = 0
for num in numbers:
    sum += num
average = sum / len(numbers)
print("\nAverage:", average)

# 3. Display values greater than threshold
print("\nValues greater than", threshold, ":")
for num in numbers:
    if num > threshold:
        print(num)

# 4. Find maximum and minimum values
maximum = numbers[0]
minimum = numbers[0]

for num in numbers:
    if num > maximum:
        maximum = num
    if num < minimum:
        minimum = num

print("\nMaximum:", maximum)
print("Minimum:", minimum)

# 5. Count elements satisfying a condition
count = 0
for num in numbers:
    if num > threshold:
        count += 1

print("Count of values greater than", threshold, "=", count)
