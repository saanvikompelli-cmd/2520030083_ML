# %% [markdown]
# <a href="https://colab.research.google.com/github/saanvikompelli-cmd/2520030083_ML/blob/main/Python_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a python program to declare variables of int, float, string, and boolean and display their values along with their data types.

# %%
x=5
y=3.14
name="CGPA"
is_placed= True
print(x,type(x))
print(y,type(y))
print(name,type(name))
print(is_placed,type(is_placed))
# Out:
# 5 <class 'int'>
# 3.14 <class 'float'>
# CGPA <class 'str'>
# True <class 'bool'>

# %% [markdown]
# Write a program to check the data type of different variables using the type function.

# %%
age = 19
name = "Saanvi"
is_student = True

print(type(age))
print(type(name))
print(type(is_student))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
